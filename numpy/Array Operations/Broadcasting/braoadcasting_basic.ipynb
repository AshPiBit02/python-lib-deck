# %% [markdown]
# # Broadcasting with 1D Array

# %%
import numpy as np 
arr=np.arange(1,6,1)

# %%
# Add 10 to every element.
print(arr+10)
# Out:
# [11 12 13 14 15]

# %%
# Multiply every element by 5.
print(arr*5)
# Out:
# [ 5 10 15 20 25]

# %%
# Compute (arr+5)/2
print((arr+5)/2)
# Out:
# [3.  3.5 4.  4.5 5. ]

# %% [markdown]
# # Similarly 2D Array
