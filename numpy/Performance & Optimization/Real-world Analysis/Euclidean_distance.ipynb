# %% [markdown]
# Computing pairwise Euclidean distance between 1000 points in 3D space

# %%
import numpy as np 
np.random.seed(4)
points = np.random.rand(1000, 3)

# %%
diff=points[:,np.newaxis,:]-points[np.newaxis,:,:]
print(diff.shape)
# Out:
# (1000, 1000, 3)
