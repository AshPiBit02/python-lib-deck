# %% [markdown]
# # Functions & Methods

# %%
          Operation      Type                           Description
0     pd.read_csv()  Function         Reads CSV file into DataFrame
1   pd.read_excel()  Function                       Read Excel file
2    pd.read_json()  Function                       Reads JSON file
3       df.to_csv()    Method               Writes DataFrame to CSV
4     df.to_excel()    Method             Writes DataFrame to Excel
5      df.to_json()    Method              Writes DataFrame to JSON
6    df.set_index()    Method               Set index after loading
7  df.reset_index()    Method  Reset index back to default integers

# %% [markdown]
# # Elements and Parameters

# %%
  Element/Parameter                      Purpose
0         index_col        Set a column as index
1           usecols      Select specific columns
2             nrows       Read only first n rows
3          skiprows            Skip certain rows
4            header  Define row for column names
5               sep      Define delimiter in CSV
6        sheet_name           Select Excel sheet
7         chunksize    Read large files in parts
8            orient               JSON Sturcture
9             lines            JSON lines format
